# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

train = pd.read_csv('C:/Users/CHI011/Downloads/train 4.csv')

# %% [markdown]
# Check the vital statistics of the dataset using the type and shape attributes.

# %%
print("Data type : ", type(train))
print("Data dims : ", train.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1460, 81)

# %% [markdown]
# Check the variables (and their types) in the dataset using the dtypes attribute.

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Problem 1a
#
# We will start by setting up a Uni-Variate Linear Regression problem.
#
# Response Variable : **SalePrice**
# Predictor Feature : **GrLivArea**
#
# > Regression Model : SalePrice = $a$ $\times$ GrLivArea + $b$
#
# Extract the variables and the associated data as a Pandas `DataFrame`.

# %%
# Recall the SalePrice - GrLivArea Dataset
SalePrice = pd.DataFrame(train['SalePrice'])         # Response
GrLivArea = pd.DataFrame(train['GrLivArea'])         # Predictor

# %%
# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(GrLivArea, SalePrice, test_size = 0.25)

# %%
# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model
# Out:
# LinearRegression()

# %%
# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [20149.96852363]
# Coefficients of Regression 	: a =  [[105.86261642]]

# %%
# Predict SalePrice values corresponding to GrLivArea
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# %%
print("Plot the linear regrssion line on Train Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_train, y_train, color = "blue")
plt.scatter(X_train, y_train_pred, color = "red")
plt.show()

print("Plot the linear regrssion line on Test Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()
# Out:
# Plot the linear regrssion line on Train Set
# Plot the linear regrssion line on Test Set

# %% [markdown]
# # Problem 1b

# %%
# Check the Goodness of Fit (on Train Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.49857278874382605
# Mean Squared Error (MSE) 	: 3203862727.230643
# Root Mean Squared Error (RMSE) 	: 56602.674205647236

# %%
# Check the Goodness of Fit (on Test Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5126523479209122
# Mean Squared Error (MSE) 	: 2950021740.1205263
# Root Mean Squared Error (RMSE) 	: 56602.674205647236

# %%
# Plot the Predictions vs the True values
# Chosen metrics for Prediction Accuracy
f, axes = plt.subplots(1, 2, figsize=(20, 7))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %% [markdown]
# # Problem 2a - TotalBsmtSF

# %%
# Recall the SalePrice - TotalBsmtSF Dataset
SalePrice = pd.DataFrame(train['SalePrice'])         # Response
TotalBsmtSF = pd.DataFrame(train['TotalBsmtSF'])         # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(TotalBsmtSF, SalePrice, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict SalePrice values corresponding to TotalBsmtSF
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Linear Regression Lines
print("Plot the linear regression line on Train Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_train, y_train, color = "blue")
plt.scatter(X_train, y_train_pred, color = "red")
plt.show()

print("Plot the linear regression line on Test Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# Check the Goodness of Fit (on Train Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

# Check the Goodness of Fit (on Test Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

# Plot the Predictions vs the True values
# Chosen metrics for Prediction Accuracy
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Intercept of Regression 	: b =  [69853.31495732]
# Coefficients of Regression 	: a =  [[103.83642557]]
#
# Plot the linear regression line on Train Set
# Plot the linear regression line on Test Set
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.3567262264816832
# Mean Squared Error (MSE) 	: 3849613913.037761
# Root Mean Squared Error (RMSE) 	: 62045.256974548516
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.417020159727865
# Mean Squared Error (MSE) 	: 4227895607.284404
# Root Mean Squared Error (RMSE) 	: 62045.256974548516

# %% [markdown]
# # Problem 2b - GarageArea

# %%
# Recall the SalePrice - GarageArea Dataset
SalePrice = pd.DataFrame(train['SalePrice'])         # Response
GarageArea = pd.DataFrame(train['GarageArea'])         # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(GarageArea, SalePrice, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict SalePrice values corresponding to GarageArea
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Linear Regression Lines
print("Plot the linear regression line on Train Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_train, y_train, color = "blue")
plt.scatter(X_train, y_train_pred, color = "red")
plt.show()

print("Plot the linear regression line on Test Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# Check the Goodness of Fit (on Train Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

# Check the Goodness of Fit (on Test Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

# Plot the Predictions vs the True values
# Chosen metrics for Prediction Accuracy
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Intercept of Regression 	: b =  [69683.75410855]
# Coefficients of Regression 	: a =  [[235.03407036]]
#
# Plot the linear regression line on Train Set
# Plot the linear regression line on Test Set
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.391100398959757
# Mean Squared Error (MSE) 	: 4025350254.8724174
# Root Mean Squared Error (RMSE) 	: 63445.64803729581
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.37920346394637994
# Mean Squared Error (MSE) 	: 3348265399.5775633
# Root Mean Squared Error (RMSE) 	: 63445.64803729581

# %% [markdown]
# # Problem 3a

# %%
#List Outliers
def get_outlier_indexes(df, col_name):
    Q1 = df[col_name].quantile(0.25)
    Q3 = df[col_name].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_indexes = df[(df[col_name] < lower_bound) | (df[col_name] > upper_bound)].index.tolist()
    return outlier_indexes

# %%
GrLivArea_outliers = get_outlier_indexes(GrLivArea, 'GrLivArea')
print(GrLivArea_outliers)
# Out:
# [58, 118, 185, 197, 231, 304, 324, 496, 523, 583, 608, 635, 691, 769, 798, 803, 961, 1024, 1031, 1046, 1142, 1169, 1173, 1175, 1182, 1268, 1298, 1312, 1328, 1353, 1386]

# %%
SalePrice_outliers = get_outlier_indexes(SalePrice, 'SalePrice')
print(SalePrice_outliers)
# Out:
# [11, 53, 58, 112, 151, 161, 178, 185, 224, 231, 278, 309, 313, 320, 321, 336, 349, 378, 389, 440, 473, 477, 481, 496, 515, 527, 585, 591, 608, 642, 644, 654, 661, 664, 678, 688, 691, 702, 718, 769, 774, 798, 803, 825, 877, 898, 987, 990, 1046, 1142, 1169, 1181, 1182, 1228, 1243, 1267, 1268, 1353, 1373, 1388, 1437]

# %%
#union of outliers - identified by their indexes
outliers_indexes = GrLivArea_outliers + SalePrice_outliers
print(outliers_indexes)
# Out:
# [58, 118, 185, 197, 231, 304, 324, 496, 523, 583, 608, 635, 691, 769, 798, 803, 961, 1024, 1031, 1046, 1142, 1169, 1173, 1175, 1182, 1268, 1298, 1312, 1328, 1353, 1386, 11, 53, 58, 112, 151, 161, 178, 185, 224, 231, 278, 309, 313, 320, 321, 336, 349, 378, 389, 440, 473, 477, 481, 496, 515, 527, 585, 591, 608, 642, 644, 654, 661, 664, 678, 688, 691, 702, 718, 769, 774, 798, 803, 825, 877, 898, 987, 990, 1046, 1142, 1169, 1181, 1182, 1228, 1243, 1267, 1268, 1353, 1373, 1388, 1437]

# %%
GrLivArea_clean = GrLivArea.drop(index = outliers_indexes)
print(GrLivArea_clean)
# Out:
#       GrLivArea
# 0          1710
# 1          1262
# 2          1786
# 3          1717
# 4          2198
# ...         ...
# 1455       1647
# 1456       2073
# 1457       2340
# 1458       1078
# 1459       1256
#
# [1383 rows x 1 columns]

# %%
SalePrice_clean = SalePrice.drop(index = outliers_indexes)
print(SalePrice_clean)
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1383 rows x 1 columns]

# %% [markdown]
# # Problem 3b

# %%
# Recall the SalePrice - GrLivArea Dataset
SalePrice = pd.DataFrame(train['SalePrice'])         # Response
GrLivArea = pd.DataFrame(train['GrLivArea'])         # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(GrLivArea, SalePrice, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict SalePrice values corresponding to GrLivArea
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

print("Plot the linear regrssion line on Train Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_train, y_train, color = "blue")
plt.scatter(X_train, y_train_pred, color = "red")
plt.show()

print("Plot the linear regrssion line on Test Set")
f = plt.figure(figsize=(16,8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()
# Out:
# Intercept of Regression 	: b =  [7782.20447323]
# Coefficients of Regression 	: a =  [[114.49383697]]
#
# Plot the linear regrssion line on Train Set
# Plot the linear regrssion line on Test Set

# %% [markdown]
# # Problem 3c

# %%
# Recall the SalePrice - GrLivArea Dataset
SalePrice = pd.DataFrame(train['SalePrice'])         # Response
GrLivArea = pd.DataFrame(train['GrLivArea'])         # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(GrLivArea, SalePrice, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict SalePrice values corresponding to GrLivArea
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

# Check the Goodness of Fit (on Test Data)
# Chosen metrics for Goodness of Fit
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

# Plot the Predictions vs the True values
# Chosen metrics for Prediction Accuracy
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Intercept of Regression 	: b =  [18496.41146011]
# Coefficients of Regression 	: a =  [[108.05436612]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.49960217505456683
# Mean Squared Error (MSE) 	: 3311691190.752685
# Root Mean Squared Error (RMSE) 	: 57547.295251407646
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5060176599095418
# Mean Squared Error (MSE) 	: 2632292635.392685
# Root Mean Squared Error (RMSE) 	: 57547.295251407646

# %% [markdown]
# This model is better than the one in Problem 1 for the same variables.
#
# This model has lower Explained Variance (depending on which sample is used), but it also consistently has the lowest Root Mean Squared Error, which means it deviates the least from the actual data points.
#
# Thus, this model is better.
